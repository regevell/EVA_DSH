# %% [markdown]
# # mxmx HX
#
# XH
# \begin{equation}
# -\dot{m}c \theta_0 + \dot{Q}_x = -\dot{m}c \theta_o        \tag{0}
# \end{equation}
#
# \begin{equation}
# \omega_0 = \omega_o                 \tag{1}
# \end{equation}
#
# MX1
# \begin{equation}
# \alpha \dot{m}c \theta_0 - \dot{m}c \theta_1 + (1-\alpha)\dot{m}c \theta_6 = 0        \tag{2}
# \end{equation}
#
# \begin{equation}
# \alpha \dot{m}l \omega_0 - \dot{m}l \omega_1 + (1-\alpha)\dot{m}l \omega_6 = 0       \tag{3}
# \end{equation}
#
# HC1
# \begin{equation}
# \dot{m}c \theta_1 - \dot{m}c \theta_2 + \dot{Q}_{HC1} = 0        \tag{4}
# \end{equation}
#
# \begin{equation}
# \dot{m}l \omega_1 - \dot{m}l \omega_2  = 0      \tag{5}
# \end{equation}
#
# AH
# \begin{equation}
# c \theta_2 + l \omega_2 - c \theta_3 - l \omega_3 = 0       \tag{6}
# \end{equation}
#
# \begin{equation}
# \omega_{sp} \theta_3 - \omega_3 = f'(\theta_s^o)\theta_s^o - \omega_s^o           \tag{7}
# \end{equation}
#
# MX2
# \begin{equation}
# \beta \dot{m}c \theta_2 + (1-\beta) \dot{m}c \theta_3 - \dot{m}c \theta_4 = 0        \tag{8}
# \end{equation}
#
# \begin{equation}
# \beta \dot{m}l \omega_2 + (1-\beta) \dot{m}l \omega_3 - \dot{m}l \omega_4  = 0      \tag{9}
# \end{equation}
#
# HC2
# \begin{equation}
# \dot{m}c \theta_4 - \dot{m}c \theta_5 + \dot{Q}_{HC2} = 0        \tag{10}
# \end{equation}
#
# \begin{equation}
# \dot{m}l \omega_4 - \dot{m}l \omega_5  = 0      \tag{11}
# \end{equation}
#
# TZ
# \begin{equation}
# \dot{m}c \theta_5 - \dot{m}c \theta_6 + \dot{Q}_{s,TZ} = 0        \tag{12}
# \end{equation}
#
# \begin{equation}
# \dot{m}l \omega_5 - \dot{m}l \omega_6 + \dot{Q}_{l,TZ} = 0      \tag{13}
# \end{equation}
#
# BL
# \begin{equation}
# (UA + \dot{m}_i c) \theta_6 + Q_{s,TZ} = (UA + \dot{m}_i c)\theta_o + \dot{Q}_{s,aux}        \tag{14}
# \end{equation}
#
# \begin{equation}
# \dot{m}_i l \omega_6 + Q_{l,TZ} = \dot{m}_i l \omega_o \dot{Q}_{l,aux}      \tag{15}
# \end{equation}
#
# K
# \begin{equation}
# K_{\theta} \theta_6 + \dot{Q}_{HC1} = K_{\theta} \theta_{Isp}        \tag{16}
# \end{equation}
#
# \begin{equation}
# K_{\omega} \omega_6 + \dot{Q}_{HC2} = K_{\omega} \omega{Isp}       \tag{17}
# \end{equation}
#
# XC
# \begin{equation}
# (1-\beta_{HX})\dot{m}c \theta_6 - (1-\beta_{HX})\dot{m}c \theta_7 - \dot{Q}_s = 0        \tag{18}
# \end{equation}
#
# \begin{equation}
# (1-\beta_{HX})\dot{m}l \omega_6 - (1-\beta_{HX})\dot{m}l \omega_7 - \dot{Q}_l = 0      \tag{19}
# \end{equation}
#
# XM
# \begin{equation}
# \beta_{HX} \theta_6 - (1-\beta_{HX}) \theta_7 - \theta_8 = 0        \tag{20}
# \end{equation}
#
# \begin{equation}
# \beta_{HX} \omega_6 - (1-\beta_{HX}) \omega_7 - \omega_8 = 0      \tag{21}
# \end{equation}
#
# Q
# \begin{equation}
# UA_{HX} \theta_0 - UA_{HX} \theta_6 - UA_{HX} \theta_8 + 2\dot{Q}_s + 2\dot{Q}_l = -UA_{HX} \theta_{o}        \tag{22}
# \end{equation}
#
# \begin{equation}
# f'(\theta_s^o)\theta_s^o - \omega_7 = f'(\theta_s^o)\theta_s^o - \omega_s^o         \tag{23}
# \end{equation}
#
# \begin{equation}
# \dot{Q}_x - \dot{Q}_l - \dot{Q}_s = 0         \tag{24}
# \end{equation}

# %% [markdown]
# # mamx HX
#
# !!! INDICIES NOT CORRECT YET !!!
#
# XH
# \begin{equation}
# -\dot{m}c \theta_0 + \dot{Q}_x = -\dot{m}c \theta_o        \tag{0}
# \end{equation}
#
# \begin{equation}
# \omega_0 = \omega_o                 \tag{1}
# \end{equation}
#
# MX1
# \begin{equation}
# \alpha \dot{m}c \theta_0 - \dot{m}c \theta_1 + (1-\alpha)\dot{m}c \theta_8 = 0        \tag{2}
# \end{equation}
#
# \begin{equation}
# \alpha \dot{m}l \omega_0 - \dot{m}l \omega_1 + (1-\alpha)\dot{m}l \omega_8 = 0       \tag{3}
# \end{equation}
#
# MX_AD1
# \begin{equation}
# c \theta_1 + l \omega_1 - c \theta_2 - l \omega_2 = 0       \tag{4}
# \end{equation}
#
# \begin{equation}
# f'(\theta_s^o)\theta_2 - \omega_2 = f'(\theta_s^o)\theta_s^o - \omega_s^o           \tag{5}
# \end{equation}
#
# HC1
# \begin{equation}
# \dot{m}c \theta_2 - \dot{m}c \theta_3 + \dot{Q}_{HC1} = 0        \tag{6}
# \end{equation}
#
# \begin{equation}
# \dot{m}l \omega_2 - \dot{m}l \omega_3  = 0      \tag{7}
# \end{equation}
#
# AH
# \begin{equation}
# c \theta_3 + l \omega_3 - c \theta_4 - l \omega_4 = 0       \tag{8}
# \end{equation}
#
# \begin{equation}
# \omega_{sp} \theta_4 - \omega_4 = f'(\theta_s^o)\theta_s^o - \omega_s^o           \tag{9}
# \end{equation}
#
# MX2
# \begin{equation}
# \beta \dot{m}c \theta_3 + (1-\beta) \dot{m}c \theta_4 - \dot{m}c \theta_5 = 0        \tag{10}
# \end{equation}
#
# \begin{equation}
# \beta \dot{m}l \omega_3 + (1-\beta) \dot{m}l \omega_4 - \dot{m}l \omega_5  = 0      \tag{11}
# \end{equation}
#
# MX_AD2
# \begin{equation}
# c \theta_5 + l \omega_5 - c \theta_6 - l \omega_6 = 0       \tag{12}
# \end{equation}
#
# \begin{equation}
# f'(\theta_s^o)\theta_6 - \omega_6 = f'(\theta_s^o)\theta_s^o - \omega_s^o           \tag{13}
# \end{equation}
#
# HC2
# \begin{equation}
# \dot{m}c \theta_4 - \dot{m}c \theta_5 + \dot{Q}_{HC2} = 0        \tag{14}
# \end{equation}
#
# \begin{equation}
# \dot{m}l \omega_4 - \dot{m}l \omega_5  = 0      \tag{15}
# \end{equation}
#
# TZ
# \begin{equation}
# \dot{m}c \theta_5 - \dot{m}c \theta_6 + \dot{Q}_{s,TZ} = 0        \tag{16}
# \end{equation}
#
# \begin{equation}
# \dot{m}l \omega_5 - \dot{m}l \omega_6 + \dot{Q}_{l,TZ} = 0      \tag{17}
# \end{equation}
#
# BL
# \begin{equation}
# (UA + \dot{m}_i c) \theta_6 + Q_{s,TZ} = (UA + \dot{m}_i c)\theta_o + \dot{Q}_{s,aux}        \tag{18}
# \end{equation}
#
# \begin{equation}
# \dot{m}_i l \omega_6 + Q_{l,TZ} = \dot{m}_i l \omega_o \dot{Q}_{l,aux}      \tag{19}
# \end{equation}
#
# K
# \begin{equation}
# K_{\theta} \theta_6 + \dot{Q}_{HC1} = K_{\theta} \theta_{Isp}        \tag{20}
# \end{equation}
#
# \begin{equation}
# K_{\omega} \omega_6 + \dot{Q}_{HC2} = K_{\omega} \omega{Isp}       \tag{21}
# \end{equation}
#
# XC
# \begin{equation}
# (1-\beta_{HX})\dot{m}c \theta_6 - (1-\beta_{HX})\dot{m}c \theta_7 - \dot{Q}_s = 0        \tag{22}
# \end{equation}
#
# \begin{equation}
# (1-\beta_{HX})\dot{m}l \omega_6 - (1-\beta_{HX})\dot{m}l \omega_7 - \dot{Q}_l = 0      \tag{23}
# \end{equation}
#
# XM
# \begin{equation}
# \beta_{HX} \theta_6 - (1-\beta_{HX}) \theta_7 - \theta_8 = 0        \tag{24}
# \end{equation}
#
# \begin{equation}
# \beta_{HX} \omega_6 - (1-\beta_{HX}) \omega_7 - \omega_8 = 0      \tag{25}
# \end{equation}
#
# Q
# \begin{equation}
# UA_{HX} \theta_0 - UA_{HX} \theta_6 - UA_{HX} \theta_8 + 2\dot{Q}_s + 2\dot{Q}_l = -UA_{HX} \theta_{o}        \tag{26}
# \end{equation}
#
# \begin{equation}
# f'(\theta_s^o)\theta_s^o - \omega_7 = f'(\theta_s^o)\theta_s^o - \omega_s^o         \tag{27}
# \end{equation}
#
# \begin{equation}
# \dot{Q}_x - \dot{Q}_l - \dot{Q}_s = 0         \tag{28}
# \end{equation}
